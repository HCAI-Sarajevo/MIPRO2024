# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Učitavanje dataseta

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Dataset/dataset_aqi_daily.csv')
df
# Out:
#         DateTime        AQI
# 0     2018-05-22  58.000000
# 1     2018-05-23  55.000000
# 2     2018-05-24  47.958333
# 3     2018-05-25  65.125000
# 4     2018-05-26  72.750000
# ...          ...        ...
# 1810  2023-05-06  48.500000
# 1811  2023-05-07  41.375000
# 1812  2023-05-08  44.521739
# 1813  2023-05-09  29.083333
# 1814  2023-05-10  49.000000
#
# [1815 rows x 2 columns]

# %%
df2018 = df[(df['DateTime'].str.contains("2018"))]
df2019 = df[(df['DateTime'].str.contains("2019"))]
df2020 = df[(df['DateTime'].str.contains("2020"))]
df2021 = df[(df['DateTime'].str.contains("2021"))]
df2022 = df[(df['DateTime'].str.contains("2022"))]
df2023 = df[(df['DateTime'].str.contains("2023"))]
df2018
# Out:
#        DateTime         AQI
# 0    2018-05-22   58.000000
# 1    2018-05-23   55.000000
# 2    2018-05-24   47.958333
# 3    2018-05-25   65.125000
# 4    2018-05-26   72.750000
# ..          ...         ...
# 219  2018-12-27  221.608696
# 220  2018-12-28  324.708333
# 221  2018-12-29  413.166667
# 222  2018-12-30  326.541667
# 223  2018-12-31  102.000000
#
# [224 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
df2018['DateTime'] = pd.to_datetime(df2018['DateTime'], format='%Y-%m-%d')
df2018
# Out:
# <ipython-input-5-03cf8cebb30e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2018['DateTime'] = pd.to_datetime(df2018['DateTime'], format='%Y-%m-%d')
#       DateTime         AQI
# 0   2018-05-22   58.000000
# 1   2018-05-23   55.000000
# 2   2018-05-24   47.958333
# 3   2018-05-25   65.125000
# 4   2018-05-26   72.750000
# ..         ...         ...
# 219 2018-12-27  221.608696
# 220 2018-12-28  324.708333
# 221 2018-12-29  413.166667
# 222 2018-12-30  326.541667
# 223 2018-12-31  102.000000
#
# [224 rows x 2 columns]

# %%
df2019['DateTime'] = pd.to_datetime(df2019['DateTime'], format='%Y-%m-%d')
df2020['DateTime'] = pd.to_datetime(df2020['DateTime'], format='%Y-%m-%d')
df2021['DateTime'] = pd.to_datetime(df2021['DateTime'], format='%Y-%m-%d')
df2022['DateTime'] = pd.to_datetime(df2022['DateTime'], format='%Y-%m-%d')
df2023['DateTime'] = pd.to_datetime(df2023['DateTime'], format='%Y-%m-%d')
df2019
# Out:
# <ipython-input-6-e932bd8d40da>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2019['DateTime'] = pd.to_datetime(df2019['DateTime'], format='%Y-%m-%d')
# <ipython-input-6-e932bd8d40da>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2020['DateTime'] = pd.to_datetime(df2020['DateTime'], format='%Y-%m-%d')
# <ipython-input-6-e932bd8d40da>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
fig, ax = plt.subplots(figsize=(25, 12), dpi = 200)
ax.bar(df2018['DateTime'], df2018['AQI'],
       color='yellow')
plt.title('Average AQI value by day in 2018')
plt.ylabel('AQI')
plt.xlabel('Date')
plt.legend(loc='upper left')
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import seaborn as sns
# Set Seaborn style with white grid lines and gray background
sns.set(style="whitegrid", rc={"axes.facecolor": "#EAEAF2", "grid.color": "white"})
# sns.set(style="whitegrid", rc={"axes.facecolor": "#EAEAF2"})

# %%
fig, ax = plt.subplots(figsize=(20, 6), dpi = 200)
colors = ["green" if i <= 50 else "yellow" if i>50 and i<=100 else "orange" if i>100 and i<=150 else "red" if i>150 and i<=200 else "purple" if i>200 and i<=300 else "maroon" for i in df2018['AQI']]
ax.bar(df2018['DateTime'], df2018['AQI'], color=colors, edgecolor='none')

plt.title('Average AQI value per day in 2018')
plt.ylabel('AQI')
plt.xlabel('Date')
plt.legend(loc='upper left')

colorsLegend = {'Good':'green', 'Moderate':'yellow', 'Unhealthy for Sensitive Groups':'orange', 'Unhealthy':'red', 'Very Unhealthy':'purple', 'Hazardous':'maroon'}
labels = list(colorsLegend.keys())
handles = [plt.Rectangle((0,0),1,1, color=colorsLegend[label]) for label in labels]
plt.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 1), ncol=6)
# Convert date strings to datetime objects
start_date = pd.to_datetime('2017-12-01 00:00:00')
end_date = pd.to_datetime('2019-01-15 00:00:00')

ax.set_xlim(start_date, end_date)

plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, ax = plt.subplots(figsize=(20, 6), dpi = 200)
colors = ["green" if i <= 50 else "yellow" if i>50 and i<=100 else "orange" if i>100 and i<=150 else "red" if i>150 and i<=200 else "purple" if i>200 and i<=300 else "maroon" for i in df2019['AQI']]
ax.bar(df2019['DateTime'], df2019['AQI'], color=colors, edgecolor='none')

plt.title('Average AQI value per day in 2019')
plt.ylabel('AQI')
plt.xlabel('Date')
plt.legend(loc='upper left')

colorsLegend = {'Good':'green', 'Moderate':'yellow', 'Unhealthy for Sensitive Groups':'orange', 'Unhealthy':'red', 'Very Unhealthy':'purple', 'Hazardous':'maroon'}
labels = list(colorsLegend.keys())
handles = [plt.Rectangle((0,0),1,1, color=colorsLegend[label]) for label in labels]
plt.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 1), ncol=6)

# Convert date strings to datetime objects
start_date = pd.to_datetime('2018-12-15 00:00:00')
end_date = pd.to_datetime('2020-01-15 00:00:00')

ax.set_xlim(start_date, end_date)

plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, ax = plt.subplots(figsize=(20, 6), dpi = 200)
colors = ["green" if i <= 50 else "yellow" if i>50 and i<=100 else "orange" if i>100 and i<=150 else "red" if i>150 and i<=200 else "purple" if i>200 and i<=300 else "maroon" for i in df2020['AQI']]
ax.bar(df2020['DateTime'], df2020['AQI'], color=colors, edgecolor='none')

plt.title('Average AQI value per day in 2020')
plt.ylabel('AQI')
plt.xlabel('Date')
plt.legend(loc='upper left')

colorsLegend = {'Good':'green', 'Moderate':'yellow', 'Unhealthy for Sensitive Groups':'orange', 'Unhealthy':'red', 'Very Unhealthy':'purple', 'Hazardous':'maroon'}
labels = list(colorsLegend.keys())
handles = [plt.Rectangle((0,0),1,1, color=colorsLegend[label]) for label in labels]
plt.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 1), ncol=6)

# Convert date strings to datetime objects
start_date = pd.to_datetime('2019-12-15 00:00:00')
end_date = pd.to_datetime('2021-01-15 00:00:00')

ax.set_xlim(start_date, end_date)

plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, ax = plt.subplots(figsize=(20, 6), dpi = 200)
colors = ["green" if i <= 50 else "yellow" if i>50 and i<=100 else "orange" if i>100 and i<=150 else "red" if i>150 and i<=200 else "purple" if i>200 and i<=300 else "maroon" for i in df2021['AQI']]
ax.bar(df2021['DateTime'], df2021['AQI'], color=colors, edgecolor='none')

plt.title('Average AQI value per day in 2021')
plt.ylabel('AQI')
plt.xlabel('Date')
plt.legend(loc='upper left')

colorsLegend = {'Good':'green', 'Moderate':'yellow', 'Unhealthy for Sensitive Groups':'orange', 'Unhealthy':'red', 'Very Unhealthy':'purple', 'Hazardous':'maroon'}
labels = list(colorsLegend.keys())
handles = [plt.Rectangle((0,0),1,1, color=colorsLegend[label]) for label in labels]
plt.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 1), ncol=6)

# Convert date strings to datetime objects
start_date = pd.to_datetime('2020-12-15 00:00:00')
end_date = pd.to_datetime('2022-01-15 00:00:00')

ax.set_xlim(start_date, end_date)

plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, ax = plt.subplots(figsize=(20, 6), dpi = 200)
colors = ["green" if i <= 50 else "yellow" if i>50 and i<=100 else "orange" if i>100 and i<=150 else "red" if i>150 and i<=200 else "purple" if i>200 and i<=300 else "maroon" for i in df2022['AQI']]
ax.bar(df2022['DateTime'], df2022['AQI'], color=colors, edgecolor='none')

plt.title('Average AQI value per day in 2022')
plt.ylabel('AQI')
plt.xlabel('Date')
plt.legend(loc='upper left')

colorsLegend = {'Good':'green', 'Moderate':'yellow', 'Unhealthy for Sensitive Groups':'orange', 'Unhealthy':'red', 'Very Unhealthy':'purple', 'Hazardous':'maroon'}
labels = list(colorsLegend.keys())
handles = [plt.Rectangle((0,0),1,1, color=colorsLegend[label]) for label in labels]
plt.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 1), ncol=6)

# Convert date strings to datetime objects
start_date = pd.to_datetime('2021-12-15 00:00:00')
end_date = pd.to_datetime('2023-01-15 00:00:00')

ax.set_xlim(start_date, end_date)

plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df2022.index
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10',
#                ...
#                '2022-12-22', '2022-12-23', '2022-12-24', '2022-12-25',
#                '2022-12-26', '2022-12-27', '2022-12-28', '2022-12-29',
#                '2022-12-30', '2022-12-31'],
#               dtype='datetime64[ns]', name='DateTime', length=365, freq=None)

# %%
fig, ax = plt.subplots(figsize=(20, 6), dpi = 200)
colors = ["green" if i <= 50 else "yellow" if i>50 and i<=100 else "orange" if i>100 and i<=150 else "red" if i>150 and i<=200 else "purple" if i>200 and i<=300 else "maroon" for i in df2023['AQI']]
ax.bar(df2023['DateTime'], df2023['AQI'], color=colors, edgecolor='none')

plt.title('Average AQI value per day in 2023')
plt.ylabel('AQI')
plt.xlabel('Date')
plt.legend(loc='upper left')

colorsLegend = {'Good':'green', 'Moderate':'yellow', 'Unhealthy for Sensitive Groups':'orange', 'Unhealthy':'red', 'Very Unhealthy':'purple', 'Hazardous':'maroon'}
labels = list(colorsLegend.keys())
handles = [plt.Rectangle((0,0),1,1, color=colorsLegend[label]) for label in labels]
plt.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 1), ncol=6)
# Convert date strings to datetime objects
start_date = pd.to_datetime('2022-12-15 00:00:00')
end_date = pd.to_datetime('2024-01-15 00:00:00')

ax.set_xlim(start_date, end_date)

plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Assuming df2023 and df2022 are your dataframes for 2023 and 2022, respectively

# Plot for 2023
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 6), dpi=200)

# Plot for 2022
colors_2022 = ["green" if i <= 50 else "yellow" if 50 < i <= 100 else "orange" if 100 < i <= 150 else "red" if 150 < i <= 200 else "purple" if 200 < i <= 300 else "maroon" for i in df2022['AQI']]
axes[0].bar(df2022['DateTime'], df2022['AQI'], color=colors_2022, edgecolor='none')
axes[0].set_title('Average AQI value per day in 2022')
axes[0].set_ylabel('AQI')
axes[0].set_xlabel('Date')
#axes[0].legend(loc='upper left')

# Common legend
plt.legend(handles, labels, loc='center', ncol=6)

# Plot for 2023
colors_2023 = ["green" if i <= 50 else "yellow" if 50 < i <= 100 else "orange" if 100 < i <= 150 else "red" if 150 < i <= 200 else "purple" if 200 < i <= 300 else "maroon" for i in df2023['AQI']]
axes[1].bar(df2023['DateTime'], df2023['AQI'], color=colors_2023, edgecolor='none')
axes[1].set_title('Average AQI value per day in 2023')
axes[1].set_ylabel('AQI')
axes[1].set_xlabel('Date')
#axes[1].legend(loc='upper left')

colors_legend = {'Good': 'green', 'Moderate': 'yellow', 'Unhealthy for Sensitive Groups': 'orange', 'Unhealthy': 'red', 'Very Unhealthy': 'purple', 'Hazardous': 'maroon'}
labels = list(colors_legend.keys())
handles = [plt.Rectangle((0, 0), 1, 1, color=colors_legend[label]) for label in labels]
#axes[0].legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 1), ncol=6)



plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming df2023, df2022, df2021, df2020, df2019, df2018 are your dataframes for the respective years

# Plot for 2023
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(30, 10), dpi=200)

# Plot for 2023
colors_2023 = ["green" if i <= 50 else "yellow" if 50 < i <= 100 else "orange" if 100 < i <= 150 else "red" if 150 < i <= 200 else "purple" if 200 < i <= 300 else "maroon" for i in df2023['AQI']]
axes[0, 0].bar(df2023['DateTime'], df2023['AQI'], color=colors_2023, edgecolor='none')
axes[0, 0].set_title('Average AQI value per day in 2023')
axes[0, 0].set_ylabel('AQI')
axes[0, 0].set_xlabel('Date')
axes[0, 0].legend(loc='upper left')

# Plot for 2022
colors_2022 = ["green" if i <= 50 else "yellow" if 50 < i <= 100 else "orange" if 100 < i <= 150 else "red" if 150 < i <= 200 else "purple" if 200 < i <= 300 else "maroon" for i in df2022['AQI']]
axes[0, 1].bar(df2022['DateTime'], df2022['AQI'], color=colors_2022, edgecolor='none')
axes[0, 1].set_title('Average AQI value per day in 2022')
axes[0, 1].set_ylabel('AQI')
axes[0, 1].set_xlabel('Date')
axes[0, 1].legend(loc='upper left')

# Plot for 2021
colors_2021 = ["green" if i <= 50 else "yellow" if 50 < i <= 100 else "orange" if 100 < i <= 150 else "red" if 150 < i <= 200 else "purple" if 200 < i <= 300 else "maroon" for i in df2021['AQI']]
axes[0, 2].bar(df2021['DateTime'], df2021['AQI'], color=colors_2021, edgecolor='none')
axes[0, 2].set_title('Average AQI value per day in 2021')
axes[0, 2].set_ylabel('AQI')
axes[0, 2].set_xlabel('Date')
axes[0, 2].legend(loc='upper left')

# Plot for 2020
colors_2020 = ["green" if i <= 50 else "yellow" if 50 < i <= 100 else "orange" if 100 < i <= 150 else "red" if 150 < i <= 200 else "purple" if 200 < i <= 300 else "maroon" for i in df2020['AQI']]
axes[1, 0].bar(df2020['DateTime'], df2020['AQI'], color=colors_2020, edgecolor='none')
axes[1, 0].set_title('Average AQI value per day in 2020')
axes[1, 0].set_ylabel('AQI')
axes[1, 0].set_xlabel('Date')
axes[1, 0].legend(loc='upper left')

# Plot for 2019
colors_2019 = ["green" if i <= 50 else "yellow" if 50 < i <= 100 else "orange" if 100 < i <= 150 else "red" if 150 < i <= 200 else "purple" if 200 < i <= 300 else "maroon" for i in df2019['AQI']]
axes[1, 1].bar(df2019['DateTime'], df2019['AQI'], color=colors_2019, edgecolor='none')
axes[1, 1].set_title('Average AQI value per day in 2019')
axes[1, 1].set_ylabel('AQI')
axes[1, 1].set_xlabel('Date')
axes[1, 1].legend(loc='upper left')

# Plot for 2018
colors_2018 = ["green" if i <= 50 else "yellow" if 50 < i <= 100 else "orange" if 100 < i <= 150 else "red" if 150 < i <= 200 else "purple" if 200 < i <= 300 else "maroon" for i in df2018['AQI']]
axes[1, 2].bar(df2018['DateTime'], df2018['AQI'], color=colors_2018, edgecolor='none')
axes[1, 2].set_title('Average AQI value per day in 2018')
axes[1, 2].set_ylabel('AQI')
axes[1, 2].set_xlabel('Date')
axes[1, 2].legend(loc='upper left')

# Common legend
axes[1, 2].legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 1), ncol=6)

plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %%
import matplotlib.pyplot as plt

# Assuming df2023, df2022, df2021, df2020, df2019, df2018 are your dataframes for the respective years

# Plot for 2023
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(30, 10), dpi=200)

# Plot for 2018
colors_2018 = ["green" if i <= 50 else "yellow" if 50 < i <= 100 else "orange" if 100 < i <= 150 else "red" if 150 < i <= 200 else "purple" if 200 < i <= 300 else "maroon" for i in df2018['AQI']]
axes[0, 0].bar(df2018['DateTime'], df2018['AQI'], color=colors_2018, edgecolor='none')
axes[0, 0].set_title('Average AQI value per day in 2018')
axes[0, 0].set_ylabel('AQI')
axes[0, 0].set_xlabel('Date')
start_date = pd.to_datetime('2017-12-15 00:00:00')
end_date = pd.to_datetime('2019-01-15 00:00:00')

axes[0, 0].set_xlim(start_date, end_date)

# Plot for 2019
colors_2019 = ["green" if i <= 50 else "yellow" if 50 < i <= 100 else "orange" if 100 < i <= 150 else "red" if 150 < i <= 200 else "purple" if 200 < i <= 300 else "maroon" for i in df2019['AQI']]
axes[0, 1].bar(df2019['DateTime'], df2019['AQI'], color=colors_2019, edgecolor='none')
axes[0, 1].set_title('Average AQI value per day in 2019')
axes[0, 1].set_ylabel('AQI')
axes[0, 1].set_xlabel('Date')
start_date = pd.to_datetime('2018-12-15 00:00:00')
end_date = pd.to_datetime('2020-01-15 00:00:00')

axes[0, 1].set_xlim(start_date, end_date)

# Plot for 2020
colors_2020 = ["green" if i <= 50 else "yellow" if 50 < i <= 100 else "orange" if 100 < i <= 150 else "red" if 150 < i <= 200 else "purple" if 200 < i <= 300 else "maroon" for i in df2020['AQI']]
axes[0, 2].bar(df2020['DateTime'], df2020['AQI'], color=colors_2020, edgecolor='none')
axes[0, 2].set_title('Average AQI value per day in 2020')
axes[0, 2].set_ylabel('AQI')
axes[0, 2].set_xlabel('Date')
start_date = pd.to_datetime('2019-12-15 00:00:00')
end_date = pd.to_datetime('2021-01-15 00:00:00')

axes[0, 2].set_xlim(start_date, end_date)

# Plot for 2021
colors_2021 = ["green" if i <= 50 else "yellow" if 50 < i <= 100 else "orange" if 100 < i <= 150 else "red" if 150 < i <= 200 else "purple" if 200 < i <= 300 else "maroon" for i in df2021['AQI']]
axes[1, 0].bar(df2021['DateTime'], df2021['AQI'], color=colors_2021, edgecolor='none')
axes[1, 0].set_title('Average AQI value per day in 2021')
axes[1, 0].set_ylabel('AQI')
axes[1, 0].set_xlabel('Date')
start_date = pd.to_datetime('2020-12-15 00:00:00')
end_date = pd.to_datetime('2022-01-15 00:00:00')

axes[1, 0].set_xlim(start_date, end_date)

# Plot for 2022
colors_2022 = ["green" if i <= 50 else "yellow" if 50 < i <= 100 else "orange" if 100 < i <= 150 else "red" if 150 < i <= 200 else "purple" if 200 < i <= 300 else "maroon" for i in df2022['AQI']]
axes[1, 1].bar(df2022['DateTime'], df2022['AQI'], color=colors_2022, edgecolor='none')
axes[1, 1].set_title('Average AQI value per day in 2022')
axes[1, 1].set_ylabel('AQI')
axes[1, 1].set_xlabel('Date')
start_date = pd.to_datetime('2021-12-15 00:00:00')
end_date = pd.to_datetime('2023-01-15 00:00:00')

axes[1, 1].set_xlim(start_date, end_date)

# Plot for 2023
colors_2023 = ["green" if i <= 50 else "yellow" if 50 < i <= 100 else "orange" if 100 < i <= 150 else "red" if 150 < i <= 200 else "purple" if 200 < i <= 300 else "maroon" for i in df2023['AQI']]
axes[1, 2].bar(df2023['DateTime'], df2023['AQI'], color=colors_2023, edgecolor='none')
axes[1, 2].set_title('Average AQI value per day in 2023')
axes[1, 2].set_ylabel('AQI')
axes[1, 2].set_xlabel('Date')
start_date = pd.to_datetime('2022-12-15 00:00:00')
end_date = pd.to_datetime('2024-01-15 00:00:00')

axes[1, 2].set_xlim(start_date, end_date)

# Empty plot for legend
legend_axes = fig.add_axes([0, 0, 1, 1])
legend_axes.axis('off')
handles = [plt.Rectangle((0, 0), 1, 1, color=colors_legend[label]) for label in labels]
legend_axes.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 1.05), ncol=6)

plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()
# Out:
# <ipython-input-44-aff74853ba96>:80: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()  # Adjust layout to prevent overlapping

# %%
import matplotlib.pyplot as plt

# Assuming df2023, df2022, df2021, df2020, df2019, df2018 are your dataframes for the respective years

# Plot for 2023
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(20, 15), dpi=200)

# Plot for 2023
colors_2023 = ["green" if i <= 50 else "yellow" if 50 < i <= 100 else "orange" if 100 < i <= 150 else "red" if 150 < i <= 200 else "purple" if 200 < i <= 300 else "maroon" for i in df2023['AQI']]
axes[0, 0].bar(df2023['DateTime'], df2023['AQI'], color=colors_2023, edgecolor='none')
axes[0, 0].set_title('Average AQI value per day in 2023')
axes[0, 0].set_ylabel('AQI')
axes[0, 0].set_xlabel('Date')

# Plot for 2022
colors_2022 = ["green" if i <= 50 else "yellow" if 50 < i <= 100 else "orange" if 100 < i <= 150 else "red" if 150 < i <= 200 else "purple" if 200 < i <= 300 else "maroon" for i in df2022['AQI']]
axes[0, 1].bar(df2022['DateTime'], df2022['AQI'], color=colors_2022, edgecolor='none')
axes[0, 1].set_title('Average AQI value per day in 2022')
axes[0, 1].set_ylabel('AQI')
axes[0, 1].set_xlabel('Date')

# Plot for 2021
colors_2021 = ["green" if i <= 50 else "yellow" if 50 < i <= 100 else "orange" if 100 < i <= 150 else "red" if 150 < i <= 200 else "purple" if 200 < i <= 300 else "maroon" for i in df2021['AQI']]
axes[1, 0].bar(df2021['DateTime'], df2021['AQI'], color=colors_2021, edgecolor='none')
axes[1, 0].set_title('Average AQI value per day in 2021')
axes[1, 0].set_ylabel('AQI')
axes[1, 0].set_xlabel('Date')

# Plot for 2020
colors_2020 = ["green" if i <= 50 else "yellow" if 50 < i <= 100 else "orange" if 100 < i <= 150 else "red" if 150 < i <= 200 else "purple" if 200 < i <= 300 else "maroon" for i in df2020['AQI']]
axes[1, 1].bar(df2020['DateTime'], df2020['AQI'], color=colors_2020, edgecolor='none')
axes[1, 1].set_title('Average AQI value per day in 2020')
axes[1, 1].set_ylabel('AQI')
axes[1, 1].set_xlabel('Date')

# Plot for 2019
colors_2019 = ["green" if i <= 50 else "yellow" if 50 < i <= 100 else "orange" if 100 < i <= 150 else "red" if 150 < i <= 200 else "purple" if 200 < i <= 300 else "maroon" for i in df2019['AQI']]
axes[2, 0].bar(df2019['DateTime'], df2019['AQI'], color=colors_2019, edgecolor='none')
axes[2, 0].set_title('Average AQI value per day in 2019')
axes[2, 0].set_ylabel('AQI')
axes[2, 0].set_xlabel('Date')

# Plot for 2018
colors_2018 = ["green" if i <= 50 else "yellow" if 50 < i <= 100 else "orange" if 100 < i <= 150 else "red" if 150 < i <= 200 else "purple" if 200 < i <= 300 else "maroon" for i in df2018['AQI']]
axes[2, 1].bar(df2018['DateTime'], df2018['AQI'], color=colors_2018, edgecolor='none')
axes[2, 1].set_title('Average AQI value per day in 2018')
axes[2, 1].set_ylabel('AQI')
axes[2, 1].set_xlabel('Date')

# Common legend
handles = [plt.Rectangle((0, 0), 1, 1, color=colors_legend[label]) for label in labels]
fig.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 1.05), ncol=6)

plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

# %%
df2018['DateTime'].max()
# Out:
# Timestamp('2018-12-31 00:00:00')
